# %%
html = '''
<!DOCTYPE html>
<html>
<head>
<meta charset="UTF-8">
<title>second</title>
<style>
*{
text-align: center;
color: red;
}
</style>
</head>

<body>
 <h2>美丽的汤</h2>
<p class="test" id='num1'>我爱学习</p>
<p class="test2" id='num2'>学习爱我</p>
<p class="test" id='num3'>学习CSS</p>
</body>
</html>
'''
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'lxml')

print(soup.prettify())  # prettify可以打印格式很好的html
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    second
#   </title>
#   <style>
#    *{
# text-align: center;
# color: red;
# }
#   </style>
#  </head>
#  <body>
#   <h2>
#    美丽的汤
#   </h2>
#   <p class="test" id="num1">
#    我爱学习
#   </p>
#   <p class="test2" id="num2">
#    学习爱我
#   </p>
#   <p class="test" id="num3">
#    学习CSS
#   </p>
#  </body>
# </html>

# %%
t=soup.title.string
print(t)
# Out:
# second

# %%
p2=soup.find_all('p')
print(p2)
# Out:
# [<p class="test" id="num1">我爱学习</p>, <p class="test2" id="num2">学习爱我</p>, <p class="test" id="num3">学习CSS</p>]

# %%
h=soup.h2.string
print(h)
# Out:
# 美丽的汤

# %%
p=soup.p.string
print(p)
# Out:
# 我爱学习

# %%
p3=p2[1].string
print(p3)
# Out:
# 学习爱我

# %%
p3=p2[1].string
print(p3)
p4=p2[1].get_text()
print(p4)
# Out:
# 学习爱我
# 学习爱我

# %% [markdown]
# ## 属性

# %%
text='''
<!DOCTYPE html>
<html>
<head>
<meta charset="UTF-8">
<title>属性</title>

</head>
<body>
<a href='https://www.csdn.net/' class="one" >红豆生南国，春来发几枝。</a>

<a href='https://www.zhihu.com/' id="two">愿君多采撷，此物最相思。</a>
</body>
</html>
'''
from bs4 import BeautifulSoup

soup = BeautifulSoup(text, 'lxml')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    属性
#   </title>
#  </head>
#  <body>
#   <a class="one" href="https://www.csdn.net/">
#    红豆生南国，春来发几枝。
#   </a>
#   <a href="https://www.zhihu.com/" id="two">
#    愿君多采撷，此物最相思。
#   </a>
#  </body>
# </html>

# %%
s=soup.a
# print(s)
s2=s.get('href')
print(s2)

s3=s.get('class')
print(s3)
# Out:
# https://www.csdn.net/
# ['one']

# %% [markdown]
# ## 基本使用

# %%
html = '''
<!DOCTYPE html>
<html>
<head>
<meta charset="UTF-8">
<title>second</title>
<style>
*{
text-align: center;
color: red;
}
</style>
</head>

<body>
 <h2>美丽的汤</h2>
<p class="test" id='num1'>我爱学习</p>
<p class="test2" id='num2'>学习爱我</p>
<p class="test" id='num3'>学习CSS</p>
</body>
</html>
'''
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'lxml')

print(soup.prettify())  # prettify可以打印格式很好的html
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    second
#   </title>
#   <style>
#    *{
# text-align: center;
# color: red;
# }
#   </style>
#  </head>
#  <body>
#   <h2>
#    美丽的汤
#   </h2>
#   <p class="test" id="num1">
#    我爱学习
#   </p>
#   <p class="test2" id="num2">
#    学习爱我
#   </p>
#   <p class="test" id="num3">
#    学习CSS
#   </p>
#  </body>
# </html>

# %%
p2=soup.find_all('p')
print(p2)
# Out:
# [<p class="test" id="num1">我爱学习</p>, <p class="test2" id="num2">学习爱我</p>, <p class="test" id="num3">学习CSS</p>]

# %%
p3=p2[1].string
print(p3)
# Out:
# 学习爱我

# %% [markdown]
# ## 案例二

# %%
html='''
<html>
 <head>
 	<meta charset="UTF-8">
  <title>再来一碗美丽的汤</title>
 </head>
 <body>
  <h2>
   崔九欲往南山马上口号与别
  </h2>
  
  <p>
  归山深浅去
  </p>
  <a href="https://www.baidu.com/" id="link1">
  须尽丘壑美。
  </a>
  <a href="https://cn.bing.com/" id="link2">
 莫学武陵人
  </a>
  <p>
 暂游桃源里。
  <b class="boldtext">
    这是一首诗
   </b>
<b class="boldtext2">
     唐代的诗歌
</b>
  </p>
 </body>
</html>
'''

from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'lxml')

print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    再来一碗美丽的汤
#   </title>
#  </head>
#  <body>
#   <h2>
#    崔九欲往南山马上口号与别
#   </h2>
#   <p>
#    归山深浅去
#   </p>
#   <a href="https://www.baidu.com/" id="link1">
#    须尽丘壑美。
#   </a>
#   <a href="https://cn.bing.com/" id="link2">
#    莫学武陵人
#   </a>
#   <p>
#    暂游桃源里。
#    <b class="boldtext">
#     这是一首诗
#    </b>
#    <b class="boldtext2">
#     唐代的诗歌
#    </b>
#   </p>
#  </body>
# </html>

# %%
a=soup.find_all('a')
print(a)
# Out:
# [<a href="https://www.baidu.com/" id="link1">
#   须尽丘壑美。
#   </a>, <a href="https://cn.bing.com/" id="link2">
#  莫学武陵人
#   </a>]

# %%
b=soup.find_all('b')
print(b)
# Out:
# [<b class="boldtext">
#     这是一首诗
#    </b>, <b class="boldtext2">
#      唐代的诗歌
# </b>]

# %%
b2=b[1]
print(b2)
# Out:
# <b class="boldtext2">
#      唐代的诗歌
# </b>

# %%
t=soup.titleb3=soup.find_all('b','boldtext2')
print(b3)t=soup.title
# Out:
# [<b class="boldtext2">
#      唐代的诗歌
# </b>]

# %% [markdown]
# ### 标签搜素

# %%
n = soup.find_all('title')
print(n)
# Out:
# [<title>再来一碗美丽的汤</title>]

# %%
n2=soup.find_all(id='link1')
print(n2)
# Out:
# [<a href="https://www.baidu.com/" id="link1">
#   须尽丘壑美。
#   </a>]

# %%
import re
n3=soup.find(string=re.compile('诗歌'))
print(n3)
# Out:
#      唐代的诗歌

# %%
n3 =soup.find_all(['title','p'])
print(n3)
# Out:
# [<title>再来一碗美丽的汤</title>, <p>
#   归山深浅去
#   </p>, <p>
#  暂游桃源里。
#   <b class="boldtext">
#     这是一首诗
#    </b>
# <b class="boldtext2">
#      唐代的诗歌
# </b>
# </p>]

# %% [markdown]
# ### ksw参数

# %%
n2=soup.find_all(id='link1')
print(n2)
# Out:
# [<a href="https://www.baidu.com/" id="link1">
#   须尽丘壑美。
#   </a>]

# %% [markdown]
# ## CSS获取

# %%
html3='''
html_doc = """
<html><head><title>CSS获取</title></head>
<body>
<p class="title"><b></b></p>

<p class="story">美人卷珠帘，</p>

<a href="https://www.baidu.com/" class="shi" id="link1">深坐蹙蛾眉。</a>,
<a href="https://cn.bing.com/" class="shi" id="link2">但见泪痕湿，</a> and
<a href="https://www.google.com/?hl=zh_CN" class="shi" id="link3">不知心恨谁。</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""
'''
from bs4 import BeautifulSoup

soup = BeautifulSoup(html3, 'lxml')

print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    html_doc = """
#   </p>
#   <title>
#    CSS获取
#   </title>
#   <p class="title">
#    <b>
#    </b>
#   </p>
#   <p class="story">
#    美人卷珠帘，
#   </p>
#   <a class="shi" href="https://www.baidu.com/" id="link1">
#    深坐蹙蛾眉。
#   </a>
#   ,
#   <a class="shi" href="https://cn.bing.com/" id="link2">
#    但见泪痕湿，
#   </a>
#   and
#   <a class="shi" href="https://www.google.com/?hl=zh_CN" id="link3">
#    不知心恨谁。
#   </a>
#   ;
# and they lived at the bottom of a well.
#   <p class="story">
#    ...
#   </p>
#   """
#  </body>
# </html>

# %%
c=soup.find_all('a',class_='shi')
print(c)
# Out:
# [<a class="shi" href="https://www.baidu.com/" id="link1">深坐蹙蛾眉。</a>, <a class="shi" href="https://cn.bing.com/" id="link2">但见泪痕湿，</a>, <a class="shi" href="https://www.google.com/?hl=zh_CN" id="link3">不知心恨谁。</a>]

# %%
c2=soup.find_all(class_=re.compile("不知心恨谁。"))
print(c2)
# Out:
# []

# %%
c3 =soup.find_all("p", class_="story")
print(c3)
# Out:
# [<p class="story">美人卷珠帘，</p>, <p class="story">...</p>]

# %%
c4 = soup.find_all("a", id="link2")
print(c4)
# Out:
# [<a class="shi" href="https://cn.bing.com/" id="link2">但见泪痕湿，</a>]

# %% [markdown]
# ### 文本获取

# %%
w = soup.find_all(string="但见泪痕湿，")
print(w)
# Out:
# ['但见泪痕湿，']

# %%
w2 = soup.find_all(string=re.compile("美人"))
print(w2)
# Out:
# ['美人卷珠帘，']

# %%
w3=  soup.find_all('a',string="但见泪痕湿，")
print(w3)
# Out:
# [<a class="shi" href="https://cn.bing.com/" id="link2">但见泪痕湿，</a>]

# %%
w4=  soup.find_all('a',string=re.compile("不知"))
print(w4)
# Out:
# [<a class="shi" href="https://www.google.com/?hl=zh_CN" id="link3">不知心恨谁。</a>]

# %% [markdown]
# ## 输出限制

# %%
html3='''
html_doc = """
<html><head><title>CSS获取</title></head>
<body>
<p class="title"><b></b></p>

<p class="story">美人卷珠帘，</p>

<a href="https://www.baidu.com/" class="shi" id="link1">深坐蹙蛾眉。</a>,
<a href="https://cn.bing.com/" class="shi" id="link2">但见泪痕湿，</a> and
<a href="https://www.google.com/?hl=zh_CN" class="shi" id="link3">不知心恨谁。</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""
'''
from bs4 import BeautifulSoup

soup = BeautifulSoup(html3, 'lxml')

a = soup.find_all('a',limit=2)
print(a)
# Out:
# [<a class="shi" href="https://www.baidu.com/" id="link1">深坐蹙蛾眉。</a>, <a class="shi" href="https://cn.bing.com/" id="link2">但见泪痕湿，</a>]

# %%
a2=soup.find('a')
print(a2)
# Out:
# <a class="shi" href="https://www.baidu.com/" id="link1">深坐蹙蛾眉。</a>

# %%
a3= soup.find('a',recursive= False)
print(a3)
# Out:
# None

# %% [markdown]
# ## find的使用

# %%
html3='''
html_doc = """
<html><head><title>CSS获取</title></head>
<body>
<p class="title"><b></b></p>

<p class="story">美人卷珠帘，</p>

<a href="https://www.baidu.com/" class="shi" id="link1">深坐蹙蛾眉。</a>,
<a href="https://cn.bing.com/" class="shi" id="link2">但见泪痕湿，</a> and
<a href="https://www.google.com/?hl=zh_CN" class="shi" id="link3">不知心恨谁。</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""
'''
from bs4 import BeautifulSoup

soup = BeautifulSoup(html3, 'lxml')

print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    html_doc = """
#   </p>
#   <title>
#    CSS获取
#   </title>
#   <p class="title">
#    <b>
#    </b>
#   </p>
#   <p class="story">
#    美人卷珠帘，
#   </p>
#   <a class="shi" href="https://www.baidu.com/" id="link1">
#    深坐蹙蛾眉。
#   </a>
#   ,
#   <a class="shi" href="https://cn.bing.com/" id="link2">
#    但见泪痕湿，
#   </a>
#   and
#   <a class="shi" href="https://www.google.com/?hl=zh_CN" id="link3">
#    不知心恨谁。
#   </a>
#   ;
# and they lived at the bottom of a well.
#   <p class="story">
#    ...
#   </p>
#   """
#  </body>
# </html>

# %%
s=soup.find_all('title',limit=1)
s2=soup.find('title')
print(s)
print(s2)
# Out:
# [<title>CSS获取</title>]
# <title>CSS获取</title>

# %%
s3=soup.find_all('efe')
print(s3)
s4=soup.find('dv')
print(s4)
# Out:
# []
# None

# %%
s5=soup.find('body').find('a')
print(s5)

s6=soup.body.a
print(s6)
# Out:
# <a class="shi" href="https://www.baidu.com/" id="link1">深坐蹙蛾眉。</a>
# <a class="shi" href="https://www.baidu.com/" id="link1">深坐蹙蛾眉。</a>

# %% [markdown]
# ## 网页文档处理

# %%
from bs4 import BeautifulSoup
# 从档案读取HTML文档处理
with  open ( "index.html " ) as f: 
    soup = BeautifulSoup(f)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    second
#   </title>
#   <style>
#    *{
# 				text-align: center;
# 				color: red;
# 			}
#   </style>
#  </head>
#  <body>
#   <p class="test" id="num1">
#    鎴戠埍瀛︿範
#   </p>
#   <p class="test2" id="num2">
#    瀛︿範鐖辨垜
#   </p>
#   <p class="test" id="num3">
#    瀛︿範CSS
#   </p>
#  </body>
# </html>

# %% [markdown]
# ## CSS选择器

# %%
html4='''
html_doc = """
<html><head><title>CSS获取</title></head>
<body>
<p class="title"><b></b></p>

<p class="story">美人卷珠帘，</p>

<a href="https://www.baidu.com/" class="shi1" id="link1">深坐蹙蛾眉。</a>,
<a href="https://cn.bing.com/" class="shi" id="link2">但见泪痕湿，</a> and
<a href="https://www.google.com/?hl=zh_CN" class="shi2" id="link3">不知心恨谁。</a>
"""
'''
from bs4 import BeautifulSoup

soup = BeautifulSoup(html4, 'lxml')

print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    html_doc = """
#   </p>
#   <title>
#    CSS获取
#   </title>
#   <p class="title">
#    <b>
#    </b>
#   </p>
#   <p class="story">
#    美人卷珠帘，
#   </p>
#   <a class="shi1" href="https://www.baidu.com/" id="link1">
#    深坐蹙蛾眉。
#   </a>
#   ,
#   <a class="shi" href="https://cn.bing.com/" id="link2">
#    但见泪痕湿，
#   </a>
#   and
#   <a class="shi2" href="https://www.google.com/?hl=zh_CN" id="link3">
#    不知心恨谁。
#   </a>
#   """
#  </body>
# </html>

# %%
s=soup.select('title')
print(s)
# Out:
# [<title>CSS获取</title>]

# %%
s=soup.select('a')
print(s)
# Out:
# [<a class="shi1" href="https://www.baidu.com/" id="link1">深坐蹙蛾眉。</a>, <a class="shi" href="https://cn.bing.com/" id="link2">但见泪痕湿，</a>, <a class="shi2" href="https://www.google.com/?hl=zh_CN" id="link3">不知心恨谁。</a>]

# %%
s2=soup.select('body title')
print(s2)
# Out:
# [<title>CSS获取</title>]

# %%
s2=soup.select('body a')
print(s2)
# Out:
# [<a class="shi1" href="https://www.baidu.com/" id="link1">深坐蹙蛾眉。</a>, <a class="shi" href="https://cn.bing.com/" id="link2">但见泪痕湿，</a>, <a class="shi2" href="https://www.google.com/?hl=zh_CN" id="link3">不知心恨谁。</a>]

# %%
s2=soup.select('body>a')
print(s2)
# Out:
# [<a class="shi1" href="https://www.baidu.com/" id="link1">深坐蹙蛾眉。</a>, <a class="shi" href="https://cn.bing.com/" id="link2">但见泪痕湿，</a>, <a class="shi2" href="https://www.google.com/?hl=zh_CN" id="link3">不知心恨谁。</a>]

# %%
s3=soup.select("body > #link2")
print(s3)
# Out:
# [<a class="shi" href="https://cn.bing.com/" id="link2">但见泪痕湿，</a>]

# %%
#按照类名查找

# %%
s4=soup.select(".shi2")
print(s4)
# Out:
# [<a class="shi2" href="https://www.google.com/?hl=zh_CN" id="link3">不知心恨谁。</a>]

# %%
s5=soup.select(".shi1")
print(s5)
# Out:
# [<a class="shi1" href="https://www.baidu.com/" id="link1">深坐蹙蛾眉。</a>]

# %%
s6=soup.select("#link2")
print(s6)
# Out:
# [<a class="shi" href="https://cn.bing.com/" id="link2">但见泪痕湿，</a>]

# %%
s7=soup.select("#link3")
print(s7)
# Out:
# [<a class="shi2" href="https://www.google.com/?hl=zh_CN" id="link3">不知心恨谁。</a>]

# %%
s8=soup.select("#link1,#link2")
print(s8)
# Out:
# [<a class="shi1" href="https://www.baidu.com/" id="link1">深坐蹙蛾眉。</a>, <a class="shi" href="https://cn.bing.com/" id="link2">但见泪痕湿，</a>]

# %%
shu=soup.select('a[href]')
print(shu)
# Out:
# [<a class="shi1" href="https://www.baidu.com/" id="link1">深坐蹙蛾眉。</a>, <a class="shi" href="https://cn.bing.com/" id="link2">但见泪痕湿，</a>, <a class="shi2" href="https://www.google.com/?hl=zh_CN" id="link3">不知心恨谁。</a>]

# %%
shu2=soup.select('a[href="https://www.baidu.com/"]')
print(shu2)
# Out:
# [<a class="shi1" href="https://www.baidu.com/" id="link1">深坐蹙蛾眉。</a>]

# %%
shu3=soup.select('a[href="https://www.baidu.com/"]')[0]
print(shu3.get_text())
print(shu3.string)
# Out:
# 深坐蹙蛾眉。
# 深坐蹙蛾眉。

# %% [markdown]
# ## 实战一

# %%
import requests
from bs4 import BeautifulSoup

url='https://www.shicimingju.com/book/hongloumeng.html'

headers={'user-agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.74 Mobile Safari/537.36'}

html=requests.get(url=url,headers=headers).content.decode('utf-8')

print(html)
# Out:
# <!DOCTYPE html>
# <html lang="zh">
# <head>
# 	<script type="text/javascript" src="https://ip.ws.126.net/ipquery"></script>
#     <script src="/newpage/js/all.js"></script>
#     <meta charset="UTF-8">
#     <title>《红楼梦》全集在线阅读_史书典籍_诗词名句网</title>
#     <meta name="viewport" content="width=device-width,user-scalable=no" />
#     <meta name="description" content="" />
#     <link rel="stylesheet" href="/public/css/www_v3.css">
#     <link rel="stylesheet" href="/public/css/font_576092_m2icqcebp7evzpvi.css">
#     <script src="/public/js/device.js"></script>
#     <script src="/public/js/jq.js"></script>
#     <script src="/public/js/www_v3.js"></script>
# </head>
# <body>
# <div id="top_bar">
#     <div id="top_bar_main">
#         <div id="top_left">
#             <a href="/"><img src="/public/image/logo.png" id="logo"/></a>
#             <div id="top_left_menu">
#                 <ul>
#                     <li><a href="/">首页</a></li>
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'lxml')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="zh">
#  <head>
#   <script src="https://ip.ws.126.net/ipquery" type="text/javascript">
#   </script>
#   <script src="/newpage/js/all.js">
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    《红楼梦》全集在线阅读_史书典籍_诗词名句网
#   </title>
#   <meta content="width=device-width,user-scalable=no" name="viewport"/>
#   <meta content="" name="description"/>
#   <link href="/public/css/www_v3.css" rel="stylesheet"/>
#   <link href="/public/css/font_576092_m2icqcebp7evzpvi.css" rel="stylesheet"/>
#   <script src="/public/js/device.js">
#   </script>
#   <script src="/public/js/jq.js">
#   </script>
#   <script src="/public/js/www_v3.js">
#   </script>
#  </head>
#  <body>
#   <div id="top_bar">
#    <div id="top_bar_main">
#     <div id="top_left">
#      <a href="/">
#       <img id="logo" src="/public/image/logo.png"/>
#      </a>
#      <div id="top_left_menu">
#       <ul>
#        <li>
#         <a href="/">
#          首页
#         </a>
#        </li>
# ...

# %%
mulu=soup.find_all(class_='book-mulu')
print(mulu)
# Out:
# [<div class="book-mulu">
# <ul>
# ...

# %%
mulu=soup.select('.book-mulu')
print(mulu)
# Out:
# [<div class="book-mulu">
# <ul>
# ...

# %%
li=mulu[0]
print(li)
# Out:
# <div class="book-mulu">
# <ul>
# ...

# %%
a=li.find_all('a')
print(a)
# Out:
# [<a href="/book/hongloumeng/1.html">第 一 回 甄士隐梦幻识通灵 贾雨村风尘怀闺秀</a>, <a href="/book/hongloumeng/2.html">第 二 回 贾夫人仙逝扬州城 冷子兴演说荣国府</a>, <a href="/book/hongloumeng/3.html">第 三 回 托内兄如海酬训教 接外孙贾母惜孤女</a>, <a href="/book/hongloumeng/4.html">第 四 回 薄命女偏逢薄命郎 葫芦僧乱判葫芦案</a>, <a href="/book/hongloumeng/5.html">第 五 回 游幻境指迷十二钗 饮仙醪曲演红楼梦</a>, <a href="/book/hongloumeng/6.html">第 六 回 贾宝玉初试云雨情 刘姥姥一进荣国府</a>, <a href="/book/hongloumeng/7.html">第 七 回 送宫花贾琏戏熙凤 宴宁府宝玉会秦钟</a>, <a href="/book/hongloumeng/8.html">第 八 回 比通灵金莺微露意 探宝钗黛玉半含酸</a>, <a href="/book/hongloumeng/9.html">第 九 回 恋风流情友入家塾 起嫌疑顽童闹学堂</a>, <a href="/book/hongloumeng/10.html">第 十 回 金寡妇贪利权受辱 张太医论病细穷源</a>, <a href="/book/hongloumeng/11.html">第十一回 庆寿辰宁府排家宴 见熙凤贾瑞起淫心</a>, <a href="/book/hongloumeng/12.html">第十二回 王熙凤毒设相思局 贾天祥正照</a>, <a href="/book/hongloumeng/13.html">第十三回 秦可卿死封龙禁尉 王熙凤协理宁国府</a>, <a href="/book/hongloumeng/14.html">第十四回 林如海捐馆扬州城 贾宝玉路谒北静王</a>, <a href="/book/hongloumeng/15.html">第十五回 王凤姐弄权铁槛寺 秦鲸卿得趣馒头庵</a>, <a href="/book/hongloumeng/16.html">第十六
# ...

# %%
for i in a:
    title = i.string
    href=i['href']
    new_url = 'https://www.shicimingju.com' + href  #拼接
    print(new_url)
    print(title)
    html=requests.get(url=new_url,headers=headers).content.decode('utf-8')
    new_soup=BeautifulSoup(html,'lxml')
    for  wenben in new_soup.find_all(class_='chapter_content'):
#             print(wenben.text)
              c=wenben.text
              with open(title +'.text', 'a', encoding='utf-8') as f:
                  f.write(c)
                  print('%s--章节下载成功！' % title)
# Out:
# https://www.shicimingju.com/book/hongloumeng/1.html
# 第 一 回 甄士隐梦幻识通灵 贾雨村风尘怀闺秀
# 第 一 回 甄士隐梦幻识通灵 贾雨村风尘怀闺秀--章节下载成功！
# https://www.shicimingju.com/book/hongloumeng/2.html
# 第 二 回 贾夫人仙逝扬州城 冷子兴演说荣国府
# 第 二 回 贾夫人仙逝扬州城 冷子兴演说荣国府--章节下载成功！
# https://www.shicimingju.com/book/hongloumeng/3.html
# 第 三 回 托内兄如海酬训教 接外孙贾母惜孤女
# 第 三 回 托内兄如海酬训教 接外孙贾母惜孤女--章节下载成功！
# https://www.shicimingju.com/book/hongloumeng/4.html
# 第 四 回 薄命女偏逢薄命郎 葫芦僧乱判葫芦案
# 第 四 回 薄命女偏逢薄命郎 葫芦僧乱判葫芦案--章节下载成功！
# https://www.shicimingju.com/book/hongloumeng/5.html
# 第 五 回 游幻境指迷十二钗 饮仙醪曲演红楼梦
# 第 五 回 游幻境指迷十二钗 饮仙醪曲演红楼梦--章节下载成功！
# https://www.shicimingju.com/book/hongloumeng/6.html
# 第 六 回 贾宝玉初试云雨情 刘姥姥一进荣国府
# 第 六 回 贾宝玉初试云雨情 刘姥姥一进荣国府--章节下载成功！
# https://www.shicimingju.com/book/hongloumeng/7.html
# 第 七 回 送宫花贾琏戏熙凤 宴宁府宝玉会秦钟
# 第 七 回 送宫花贾琏戏熙凤 宴宁府宝玉会秦钟--章节下载成功！
# https://www.shicimingju.com/book/hongloumeng/8.html
# 第 八 回 比通灵金莺微露意 探宝钗黛玉半含酸
# 第 八 回 比通灵金莺微露意 探宝钗黛玉半含酸--章节下载成功！
# https://www.shicimingju.com/book/hongloumeng/9.html
# 第 九 回 恋风流情友入家塾 起嫌疑顽童闹学堂
# ...

# %% [markdown]
# ## 实战方法二

# %%
import requests

i=1
url='https://www.shicimingju.com/book/hongloumeng/{}.html'.format(i)
print(url)

headers={'user-agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.74 Mobile Safari/537.36'}

html=requests.get(url=url,headers=headers).content.decode('utf-8')

print(html)
# Out:
# https://www.shicimingju.com/book/hongloumeng/1.html
# <!DOCTYPE html>
# <html lang="zh">
# <head>
# 	<script type="text/javascript" src="https://ip.ws.126.net/ipquery"></script>
#     <script src="/newpage/js/all.js"></script>
#     <meta charset="UTF-8">
#     <title>卷一_《虎钤经》_诗词名句网</title>
#     <meta name="viewport" content="width=device-width,user-scalable=no" />
#     <meta name="description" content="" />
#     <link rel="stylesheet" href="/public/css/www_v3.css">
#     <link rel="stylesheet" href="/public/css/font_576092_m2icqcebp7evzpvi.css">
#     <script src="/public/js/device.js"></script>
#     <script src="/public/js/jq.js"></script>
#     <script src="/public/js/www_v3.js"></script>
# </head>
# <body>
# <div id="top_bar">
#     <div id="top_bar_main">
#         <div id="top_left">
#             <a href="/"><img src="/public/image/logo.png" id="logo"/></a>
#             <div id="top_left_menu">
#                 <ul>
#                     <li><a href="/">首页</a></li>
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'lxml')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="zh">
#  <head>
#   <script src="https://ip.ws.126.net/ipquery" type="text/javascript">
#   </script>
#   <script src="/newpage/js/all.js">
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    卷一_《虎钤经》_诗词名句网
#   </title>
#   <meta content="width=device-width,user-scalable=no" name="viewport"/>
#   <meta content="" name="description"/>
#   <link href="/public/css/www_v3.css" rel="stylesheet"/>
#   <link href="/public/css/font_576092_m2icqcebp7evzpvi.css" rel="stylesheet"/>
#   <script src="/public/js/device.js">
#   </script>
#   <script src="/public/js/jq.js">
#   </script>
#   <script src="/public/js/www_v3.js">
#   </script>
#  </head>
#  <body>
#   <div id="top_bar">
#    <div id="top_bar_main">
#     <div id="top_left">
#      <a href="/">
#       <img id="logo" src="/public/image/logo.png"/>
#      </a>
#      <div id="top_left_menu">
#       <ul>
#        <li>
#         <a href="/">
#          首页
#         </a>
#        </li>
#        <li>
# ...

# %%
s=soup.find_all(class_='chapter_content')
print(s[0].get_text())
# Out:
#                 　　天功第一　　天道变化，消长万汇，契地之力，乃有成尔。天贵而地贱，天动而地静，贵者运机而贱者效力。上有其动，而下行其地矣。是以知天之施地匪专也，知地之应天有常也。生机动则应之以生，气机动则应之以气。机正则泰，机乱则否。万物列形而否泰交著，见之于地焉，岂止地之为乎？盖天道内而地道外者也。王者，天也；将，地也。将者，天也；士卒，地也。我，天也；敌，地也。由此观其所动，故负胜可知矣。王之於将也，阃外之寄，择贤授柄，举无所疑。将必内应其正，外务其顺。应以正则师律严，务以顺则臣节贞。举而御敌，讵有舆尸之患乎？君恃智以自用，倨礼而傲下，授柄匪人，任人不信，将不正应，内包犹豫之惑，外丧驭众之威矣。举而御敌，宁免失律之凶乎？师之成败见之於将焉，岂将之为乎？将之为任也，智敌万人，苟无万人之用，与愚者同矣；勇冠三军，苟无三军之用，与懦者同矣。善为将者正而能变，刚而能恤，仁而能断，勇而能详，以策驭吏士，未有不振拔勋业，以戡祸乱者也。反是，则吏士外无攻，内多离散之势。勇怯见之吏士焉，岂吏士之为乎？我之於敌也，夫功拔战胜，使敌不敢抗衡者，岂敌怯乎？由我威令整，进退肃，赏罚明也。覆兵杀将，弱国削地者，岂敌强威乎？由我不严师律故也。夫如是，亦自上而及下，自内而迨外，其犹天地之用乎。故天必藉地力，然后运四气，正生杀也；贵必藉贱力，然后能立元功而建王业也。　　地利第二　　地之形，险易殊也；地之气，寒热异也。用形与气，在知逆顺焉。昧此道者，不能得地利必矣。善用地者则不然，险而易之，易而险之也。夫居险用险必内溃，居易用易必内蹶。当有形之用，逆之者善矣。何谓险而易之？曰：简以夷其政，要以节其动，用以缓其约，不以疏慢为失也。何谓易而险之？曰：进止戒严，内外无怠，用其谨慎，不以暴急为务也。如是者，乃险易之用也。以方位观之，则寒热之气异也。当有气之用，顺之者善矣。南方之气热，北方之气寒也。其气异则水土之性必相戾，逆诸人而使之饮其地脉，食其土毛，蒙其风气，瘴疠之疾、冻涩之戾加焉。以我之不便，犯顺方之人，不有患乎？天不能以气顺人，君能以人顺气，可也。是故利不可以专一。北人之马，南人之航也，各有便焉。反是，不可措手足矣。行师者不能择而用之，斯亦更北南之所便也。冀其成功，远矣。是知地之所利者，可兼而有乎。善用兵者，择利而从之，善矣。　　人用第三　　今之世取人也，每务其多学而舍其偏技
# ...

# %%
import requests
import time

for i in range(1,121):
    url = 'https://www.shicimingju.com/book/hongloumeng/{}.html'.format(i)
    #     print(url)
    headers = {
        'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.74 Mobile Safari/537.36'}

    html = requests.get(url=url, headers=headers).content.decode('utf-8')

    #     print(html)
    from bs4 import BeautifulSoup

    soup = BeautifulSoup(html, 'lxml')

    #     print(soup.prettify())
    s = soup.find_all(class_='chapter_content')
    c = s[0].get_text()

    with open('第' + str(i) + '章.text', 'a', encoding='utf-8') as f:
        f.write(c)
        print('%s--章节下载成功！' % i)
    time.sleep(1)
# Out:
# 1--章节下载成功！
# 2--章节下载成功！
# 3--章节下载成功！
# 4--章节下载成功！
# 5--章节下载成功！
# 6--章节下载成功！
# 7--章节下载成功！
# 8--章节下载成功！
# 9--章节下载成功！
# 10--章节下载成功！
# 11--章节下载成功！
# 12--章节下载成功！
# 13--章节下载成功！
# 14--章节下载成功！
# 15--章节下载成功！
# 16--章节下载成功！
# 17--章节下载成功！
# 18--章节下载成功！
# 19--章节下载成功！
# 20--章节下载成功！
# 21--章节下载成功！
# 22--章节下载成功！
# 23--章节下载成功！
# 24--章节下载成功！
# 25--章节下载成功！
# 26--章节下载成功！
# 27--章节下载成功！
# 28--章节下载成功！
# 29--章节下载成功！
# 30--章节下载成功！
# 31--章节下载成功！
# 32--章节下载成功！
# 33--章节下载成功！
# 34--章节下载成功！
# 35--章节下载成功！
# 36--章节下载成功！
# 37--章节下载成功！
# 38--章节下载成功！
# 39--章节下载成功！
# 40--章节下载成功！
# 41--章节下载成功！
# 42--章节下载成功！
# 43--章节下载成功！
# 44--章节下载成功！
# 45--章节下载成功！
# 46--章节下载成功！
# 47--章节下载成功！
# 48--章节下载成功！
# 49--章节下载成功！
# 50--章节下载成功！
# 51--章节下载成功！
# 52--章节下载成功！
# 53--章节下载成功！
# 54--章节下载成功！
# 55--章节下载成功！
# 56--章节下载成功！
# 57--章节下载成功！
# 58--章节下载成功！
# 59--章节下载成功！
# 60--章节下载成功！
# 61--章节下载成功！
# 62--章节下载成功！
# 63--章节下载成功！
# 64--章节下载成功！
# 65--章节下载成功！
# 66--章节下载成功！
# 67--章节下载成功！
# 68--章节下载成功！
# 69--章节下载成功！
# 70--章节下载成功！
# 71--章节下载成功！
# 72--章节下载成功！
# ...

# %% [markdown]
# ## 实战二
